# %% [markdown]
# # Note
# The following notebook still needs additional documentation, right now the purpose is to demonstrate it.

# %% [markdown]
# # Importing Libraries + Loading Data

# %%
from IPython.core.display import display, HTML  
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import animation

# %%
df = pd.read_csv("velocity.csv")
df
# Out:
#       Time (ms)  Velocity
# 0             0      0.03
# 1            17      0.03
# 2            34      0.03
# 3            50      0.03
# 4            67      0.03
# ...         ...       ...
# 1314      22167      0.89
# 1315      22183      0.89
# 1316      22200      0.41
# 1317      22217      0.41
# 1318      22233      0.41
#
# [1319 rows x 2 columns]

# %%
display(df["Time (ms)"].max())
display(df["Time (ms)"].min())
display(df["Velocity"][1])
# Out:
# 22233
# 0
# 0.03

# %% [markdown]
# # Working Through <a href="https://jakevdp.github.io/blog/2012/08/18/matplotlib-animation-tutorial/">Matplotlib Animation Tutorial</a>

# %% [markdown]
# # Tracking a Line Through time

# %%
"""
Matplotlib Animation Example

author: Jake Vanderplas
email: vanderplas@astro.washington.edu
website: http://jakevdp.github.com
license: BSD
Please feel free to use and modify this, but keep the above information. Thanks!
"""

import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

x_df = df["Time (ms)"]
y_df = df["Velocity"]
x_max = df["Time (ms)"].max()
y_max = df["Velocity"].max()

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
ax = plt.axes(xlim=(0, x_max), ylim=(0, y_max))
line, = plt.plot(x_df, y_df)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = x_df[0:i]
    #print("x")
    #print(x)
    y = y_df[0:i]
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,frames=1500, interval=1, blit=False)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('basic_animation.mp4', fps=60, extra_args=['-vcodec', 'libx264'])

plt.show()

# %% [markdown]
# # Plotting a Dot and Tracking Across Velocity Curve

# %%
x_df = df["Time (ms)"]
y_df = df["Velocity"]
x_max = df["Time (ms)"].max()
y_max = df["Velocity"].max()

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
ax = plt.axes(xlim=(0, x_max), ylim=(0, y_max))
plt.plot(x_df, y_df)
line.set_color('r')
line, = plt.plot([], [], lw =10)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(x_df[i], x_df[i+1], 10)
    #print("x")
    #print(x)
    y = y_df[i]
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,frames=1200, interval=1, blit=False)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('dot_tracking_animation.mp4', fps=60, extra_args=['-vcodec', 'libx264'])

plt.show()

# %% [markdown]
# # Learning How Matplotlib plots

# %%
#plt.scatter(x_df,y_df)
plt.plot(x_df[0:100], y_df[0:100])
plt.show()

# %% [markdown]
# # Demonstration

# %%
from IPython.display import HTML

# %% [markdown]
# ## Tracking a Line Through time

# %%
HTML("""
    <video alt="test" controls>
        <source src="basic_animation.mp4" type="video/mp4">
    </video>
""")
# Out:
#     <video alt="test" controls>
#         <source src="basic_animation.mp4" type="video/mp4">
#     </video>

# %% [markdown]
# ## Plotting a Dot and Tracking Across Velocity Curve

# %%
HTML("""
    <video alt="test" controls>
        <source src="dot_tracking_animation.mp4" type="video/mp4">
    </video>
""")
# Out:
#     <video alt="test" controls>
#         <source src="dot_tracking_animation.mp4" type="video/mp4">
#     </video>
